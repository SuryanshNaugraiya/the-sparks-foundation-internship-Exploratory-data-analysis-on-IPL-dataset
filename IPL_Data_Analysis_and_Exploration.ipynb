# %% [markdown]
# # DATA ANALYSIS ON IPL DATASET

# %% [markdown]
# <img src = "iplvirat.jpg">

# %% [markdown]
# ### This project is the data analysis and data exploration on IPL Dataset to know the insights of the IPL Data.
# #### Libraries used in this project:
# * Numpy
# * Pandas
# * Matplotlib
# * Seaborn

# %% [markdown]
# #### <u>There are 18 features and 756 records in the dataset</u>
# #### Attributes of the Dataset are:
# * <b>id</b> - the unique ID of any particular match
# * <B>season</B> - year or session in which the match was held
# * <b>city</b> - city where match was conducted
# * <b>date</b> - date of the match
# * <b>team1</b> - team played the match
# * <b>team2</b> - another team which played the match
# * <b>toss_winner</b> - team who won the toss in any particular match
# * <b>toss_decision</b> - decision took by team after winning the toss i.e. bat or field
# * <b>result</b> - result of the match i.e. tie or normal
# * <b>dl_applied</b> - DLS (Duckworth - Lewis - Stern) Method applied or not
# * <b>winner</b> - winning team of the match
# * <b>win_by_run</b> - runs by which team won the match
# * <b>win_by_wickets</b> - wickets by which team won the match
# * <b>player_of_match</b> - Man or Player of the match
# * <b>venue</b> - Stadium where match was conducted
# * <b>umpire1</b> - 1st umpire on the field
# * <b>umpire2</b> - 2nd umpire on the field
# * <b>umpire3</b> - 3rd umpire of the match
# ##### The Duckworth–Lewis–Stern method (DLS) is a mathematical formulation designed to calculate the target score for the team batting second in a limited overs cricket match interrupted by weather or other circumstances.

# %%
#Importing the libraries
import pandas as pd                # numerical calculations
import numpy as np                 # data preprocessing and manipulation
import matplotlib.pyplot as plt    # data visualization
import seaborn as sns              # modern data visualization

# %%
# Importing the dataset
df = pd.read_csv("matches.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
#See first five records of the dataset
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#Check datatype and count of each attribute
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
# id                 756 non-null int64
# season             756 non-null int64
# city               749 non-null object
# date               756 non-null object
# team1              756 non-null object
# team2              756 non-null object
# toss_winner        756 non-null object
# toss_decision      756 non-null object
# result             756 non-null object
# dl_applied         756 non-null int64
# winner             752 non-null object
# win_by_runs        756 non-null int64
# win_by_wickets     756 non-null int64
# player_of_match    752 non-null object
# venue              756 non-null object
# umpire1            754 non-null object
# umpire2            754 non-null object
# umpire3            119 non-null object
# dtypes: int64(5), object(13)
# memory usage: 106.4+ KB

# %%
# Print all the columns of the dataset
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#Check the number of rows and columns
df.shape
# Out:
# (756, 18)

# %%
# Description of quantitative measures
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
# Check the unique value in season which shows us that this record has match record from year 2008 to 2019
df.season.unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
# Check the unique values in city
df.city.unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
# List all the teams in the league
df.team1.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
len(df.team2.unique()) # Here we can see that total 13 teams are there
# Out:
# 15

# %%
# Check the toss decisions
df.toss_decision.unique() #We see that there are only two decisions
# Out:
# array(['field', 'bat'], dtype=object)

# %%
# Check the result
df.result.unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
# Check the outputs of dl_applied feature (DLS Method applied or not)
df.dl_applied.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# List the names of all the venues(Stadiums)
df.venue.unique()
# Out:
# array(['Rajiv Gandhi International Stadium, Uppal',
#        'Maharashtra Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Holkar Cricket Stadium',
#        'M Chinnaswamy Stadium', 'Wankhede Stadium', 'Eden Gardens',
#        'Feroz Shah Kotla',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Green Park', 'Punjab Cricket Association Stadium, Mohali',
#        'Sawai Mansingh Stadium', 'MA Chidambaram Stadium, Chepauk',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
# ...

# %%
# Team won by maximum runs
df.loc[df['win_by_runs'].idxmax(),['winner','win_by_runs']]
# Out:
# winner         Mumbai Indians
# win_by_runs               146
# Name: 43, dtype: object

# %%
# Team won by maximum wickets
df.loc[df['win_by_wickets'].idxmax(),['winner','win_by_wickets']]
# Out:
# winner            Kolkata Knight Riders
# win_by_wickets                       10
# Name: 2, dtype: object

# %%
# Team won by minimum runs
df.loc[df[df['win_by_runs'].ge(1)].win_by_runs.idxmin(),["winner","win_by_runs"]]
# Out:
# winner         Mumbai Indians
# win_by_runs                 1
# Name: 58, dtype: object

# %%
# Team won by minimum wickets
df.loc[df[df['win_by_wickets'].ge(1)].win_by_wickets.idxmin(),["winner","win_by_wickets"]]
# Out:
# winner            Kolkata Knight Riders
# win_by_wickets                        1
# Name: 559, dtype: object

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ##### To make our plots look nice, let us set a theme in seaborn and also set the size of the plot

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ### Season having maximum number of matches

# %%
# Season having maximum number of matches
sns.countplot(df.season)

# %% [markdown]
# ### Most Successful team of the league

# %%
# Analyzing the most successful team of the league
data = df.winner.value_counts()
sns.barplot(x=data,y=data.index)

# %% [markdown]
# ### Top Players of the match

# %%
# Top Player of the Match 
top_players = df.player_of_match.value_counts()[:20]
sns.barplot(x=top_players,y=top_players.index)

# %% [markdown]
# ### Relation between toss winning and match winning

# %%
# Relation between toss winning and match winning
sns.countplot(df['toss_winner']==df['winner'])

# %% [markdown]
# ### Performance of teams in different different cities

# %%
# Performance of teams in different different cities in all seasons
x, y = 2008, 2020
while x < y:
    wins_percity = df[df['season'] == x].groupby(['winner', 'city'])['id'].count().unstack()
    plot = wins_percity.plot(kind='bar', stacked=True, title="Team wins in different cities\nSeason "+str(x))
    plot.set_xlabel("Teams")
    plot.set_ylabel("No of wins")
    plot.legend(loc='best', prop={'size':8})
    x+=1

# %% [markdown]
# ### Number of Matches played in different cities

# %%
# Number of matches played in different cities
data = df.city.value_counts()
sns.barplot(x=data,y=data.index)

# %% [markdown]
# ### Number of matches played in different stadiums

# %%
# Number of matches played in different stadiums
data = df.venue.value_counts()
sns.barplot(x=data,y=data.index)

# %% [markdown]
# ### Plot - win by runs

# %%
#plot the graph of the win by runs
df.win_by_runs.plot(color="blue")

# %% [markdown]
# ### Plot - win by wickets

# %%
# plot the graph of win by wickets
df.win_by_wickets.plot(color="blue")

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# #### Here we have tried to solve some manipulation problem based on this dataset

# %% [markdown]
# ## 1.	Print total no. of matches for the 2008 season

# %%
# No of matches for the season 2008
df[df['season']==2008].season.count()
# Out:
# 58

# %% [markdown]
# ## 2.	Print the city name where maximum /minimum no of matches conducted.

# %%
# Finding city with maximum no. of matches conducted
temp = pd.DataFrame(df.city.value_counts())
print("City with maximum number of matches conducted and number of matches:",temp.loc[temp["city"]==max(temp["city"]),'city'])
# Out:
# City with maximum number of matches conducted and number of matches: Mumbai    101
# Name: city, dtype: int64

# %%
# Finding city with minimum no. of matches conducted
temp = pd.DataFrame(df.city.value_counts())
print("City with minimum number of matches conducted and number of matches:\n",temp.loc[temp["city"]==min(temp["city"]),'city'])
# Out:
# City with minimum number of matches conducted and number of matches:
#  Bloemfontein    2
# Name: city, dtype: int64

# %% [markdown]
# ## 3.	Print total count of citywise. (Ex: Jaipur 10)

# %%
temp = pd.DataFrame(df.city.value_counts())
print(temp)
# Out:
#                 city
# Mumbai           101
# Kolkata           77
# Delhi             74
# Bangalore         66
# Hyderabad         64
# Chennai           57
# Jaipur            47
# Chandigarh        46
# Pune              38
# Durban            15
# Bengaluru         14
# Visakhapatnam     13
# Centurion         12
# Ahmedabad         12
# Mohali            10
# Rajkot            10
# Indore             9
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Cape Town          7
# Port Elizabeth     7
# Abu Dhabi          7
# Ranchi             7
# Sharjah            6
# Raipur             6
# Kochi              5
# Kanpur             4
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2

# %% [markdown]
# ## 4.	Find the team name from the columns team1 and team2 where any 1 alphabet will repeat 2 times.(Ex: Deccan Chargers , Chennai Super Kings)

# %%
print(df.team1.unique()) # Print all team names
# Out:
# ['Sunrisers Hyderabad' 'Mumbai Indians' 'Gujarat Lions'
#  'Rising Pune Supergiant' 'Royal Challengers Bangalore'
#  'Kolkata Knight Riders' 'Delhi Daredevils' 'Kings XI Punjab'
#  'Chennai Super Kings' 'Rajasthan Royals' 'Deccan Chargers'
#  'Kochi Tuskers Kerala' 'Pune Warriors' 'Rising Pune Supergiants'
#  'Delhi Capitals']

# %%
li=[]                          #Make an empty list
for i in df.team1.unique():    #iterate the team names
    for j in range(0,len(i)-1):#iterate particular team name
        if(i[j]==i[j+1]):      #Check whether any alphabet will repeat twice or not 
            li.append(i)       #Append items in list
for _ in li:
    print(_)                   #Print all the team names satisfying the condition
# Out:
# Royal Challengers Bangalore
# Chennai Super Kings
# Deccan Chargers
# Pune Warriors

# %% [markdown]
# ## 5.	Find which team  is maximum and minimum  toss winner

# %%
# Creating temporary dataframe for count the toss winning of each team
temp = pd.DataFrame(df['toss_winner'].value_counts())

# %%
# Finding team with maximum toss winning 
temp.loc[temp["toss_winner"]==max(temp['toss_winner'])]
# Out:
#                 toss_winner
# Mumbai Indians           98

# %%
# Finding team with minimum toss winning
temp.loc[temp["toss_winner"]==min(temp['toss_winner'])]
# Out:
#                         toss_winner
# Rising Pune Supergiant            6

# %% [markdown]
# ## 6.	Find maximum/minimum toss winner team on city basis

# %%
temp=df.groupby('city')
ser1=temp.count().toss_winner
print("Toss winner maximum time city wise :{}".format(ser1.loc[ser1==ser1.max()]))
print("Toss winner minimum time city wise :{}".format(ser1.loc[ser1==ser1.min()]))
# Out:
# Toss winner maximum time city wise :city
# Mumbai    101
# Name: toss_winner, dtype: int64
# Toss winner minimum time city wise :city
# Bloemfontein    2
# Name: toss_winner, dtype: int64

# %% [markdown]
# ## 7.	Check if any team is toss winner then that team will go for  bat or field i.e. print the table for toss winning team name along with bat option.

# %%
df.loc[:,['toss_winner',"toss_decision"]]
# Out:
#                      toss_winner toss_decision
# 0    Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant         field
# 2          Kolkata Knight Riders         field
# 3                Kings XI Punjab         field
# 4    Royal Challengers Bangalore           bat
# 5            Sunrisers Hyderabad         field
# 6                 Mumbai Indians         field
# 7    Royal Challengers Bangalore           bat
# 8         Rising Pune Supergiant         field
# 9                 Mumbai Indians         field
# 10         Kolkata Knight Riders         field
# 11                Mumbai Indians         field
# 12                 Gujarat Lions         field
# 13           Sunrisers Hyderabad         field
# 14              Delhi Daredevils           bat
# 15                Mumbai Indians         field
# 16   Royal Challengers Bangalore         field
# 17              Delhi Daredevils           bat
# 18               Kings XI Punjab         field
# ...

# %% [markdown]
# ## 8.	Print the total count of normal/tie matches from the column result and print the team names where the match result is tie.

# %%
# Total count of normal/tie matches
df["result"].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
# Team names where the match result is tie
df.loc[df['result']=="tie",['team1','team2']]
# Out:
#                            team1                        team2
# 33                 Gujarat Lions               Mumbai Indians
# 125             Rajasthan Royals        Kolkata Knight Riders
# 189              Kings XI Punjab          Chennai Super Kings
# 387  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400             Delhi Daredevils  Royal Challengers Bangalore
# 475             Rajasthan Royals        Kolkata Knight Riders
# 535             Rajasthan Royals              Kings XI Punjab
# 705        Kolkata Knight Riders               Delhi Capitals
# 746               Mumbai Indians          Sunrisers Hyderabad

# %% [markdown]
# ## 9.	Print total count of 0/1 from the column dl_applied

# %%
df["dl_applied"].value_counts()
# Out:
# 0    737
# 1     19
# Name: dl_applied, dtype: int64

# %% [markdown]
# ## 10.	Print the team name who won the match by highest run and lowest run

# %%
# Team who won the match by highest runs
df.loc[df['win_by_runs'].idxmax(),["winner","win_by_runs"]]
# Out:
# winner         Mumbai Indians
# win_by_runs               146
# Name: 43, dtype: object

# %%
# Team who won by lowest runs
df.loc[df[df['win_by_runs'].ge(1)].win_by_runs.idxmin(),["winner","win_by_runs"]]
# Out:
# winner         Mumbai Indians
# win_by_runs                 1
# Name: 58, dtype: object

# %% [markdown]
# ## 11.	Print the team names who won the match with the double digit and both are the same.(Ex: 66,33)

# %%
def count_digit(n):
    count=0
    copy=n
    response=None
    while copy>0:
        copy=copy//10
        count+=1
    if count==2:
        x=n//10
        rem=n%10
        if x==rem:
            response=n
    return response

# %%
temp = df[['winner','win_by_runs']]

# %%
temp["win_by_runs"]=temp['win_by_runs'].apply(count_digit)
temp= temp.dropna()
temp
# Out:
# C:\Users\Mayank Aggarwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                     winner  win_by_runs
# 60     Chennai Super Kings         33.0
# 68         Kings XI Punjab         66.0
# 122  Kolkata Knight Riders         11.0
# 174  Kolkata Knight Riders         11.0
# 181    Chennai Super Kings         55.0
# 228        Deccan Chargers         11.0
# 233    Chennai Super Kings         22.0
# 244        Deccan Chargers         33.0
# 264        Deccan Chargers         55.0
# 296    Chennai Super Kings         11.0
# 313       Rajasthan Royals         22.0
# 314          Pune Warriors         22.0
# 383    Sunrisers Hyderabad         22.0
# ...

# %% [markdown]
# ## 12.	Print the team name who won the match by highest wicket and lowest wicket

# %%
# Team won by maximum wickets
df.loc[df['win_by_wickets'].idxmax(),['winner','win_by_wickets']]
# Out:
# winner            Kolkata Knight Riders
# win_by_wickets                       10
# Name: 2, dtype: object

# %%
# Team won by lowest wickets
df.loc[df[df['win_by_wickets'].ge(1)].win_by_wickets.idxmin(),["winner","win_by_wickets"]]
# Out:
# winner            Kolkata Knight Riders
# win_by_wickets                        1
# Name: 559, dtype: object

# %% [markdown]
# ## 13.	Print the team name who won the match by o wicket

# %%
df.loc[df['win_by_wickets']==0,"winner"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Delhi Daredevils', 'Kolkata Knight Riders',
#        'Rising Pune Supergiant', 'Mumbai Indians', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', nan, 'Pune Warriors',
#        'Rising Pune Supergiants', 'Gujarat Lions', 'Delhi Capitals'],
#       dtype=object)

# %% [markdown]
# ## 14.	Print the name of the player who was player of match for more than 3 times.

# %%
temp_data = pd.DataFrame(df['player_of_match'].value_counts())
temp_data.loc[temp_data["player_of_match"]>3, 'player_of_match']
# Out:
# CH Gayle            21
# AB de Villiers      20
# DA Warner           17
# RG Sharma           17
# MS Dhoni            17
# YK Pathan           16
# SR Watson           15
# SK Raina            14
# G Gambhir           13
# AM Rahane           12
# V Kohli             12
# MEK Hussey          12
# V Sehwag            11
# DR Smith            11
# A Mishra            11
# AD Russell          11
# JH Kallis           10
# KA Pollard          10
# AT Rayudu            9
# SE Marsh             9
# SP Narine            9
# UT Yadav             8
# Harbhajan Singh      8
# RA Jadeja            8
# SR Tendulkar         8
# Rashid Khan          7
# AC Gilchrist         7
# RV Uthappa           7
# HH Pandya            6
# RR Pant              6
#                     ..
# JJ Bumrah            5
# DPMD Jayawardene     5
# SC Ganguly           5
# JP Faulkner          5
# AJ Finch             5
# DW Steyn             5
# SV Samson            5
# GJ Maxwell           5
# Sandeep Sharma       5
# ...

# %% [markdown]
# ## 15.	Print the name of the player who was player of match for maximum and minimum times

# %%
# Player with maximum no. of player of the match
pd.DataFrame(temp_data.loc[temp_data["player_of_match"]==max(temp_data['player_of_match']), 'player_of_match'])
# Out:
#           player_of_match
# CH Gayle               21

# %%
# Player with minimum no. of player of the match
pd.DataFrame(temp_data.loc[temp_data["player_of_match"]==min(temp_data['player_of_match']), 'player_of_match'])
# Out:
#                    player_of_match
# B Stanlake                       1
# MS Bisla                         1
# RE Levi                          1
# J Botha                          1
# SB Jakati                        1
# CRD Fernando                     1
# PP Ojha                          1
# S Aravind                        1
# Mohammed Siraj                   1
# TL Suman                         1
# PD Collingwood                   1
# DP Nannes                        1
# DL Vettori                       1
# JEC Franklin                     1
# Mustafizur Rahman                1
# TG Southee                       1
# A Singh                          1
# J Archer                         1
# CL White                         1
# S Anirudha                       1
# R McLaren                        1
# Q de Kock                        1
# TA Boult                         1
# RP Singh                         1
# LH Ferguson                      1
# KMDN Kulasekara                  1
# ...

# %% [markdown]
# ## 16.	Print the venue names where the team will won the match by highest run and highest wicket.

# %%
# Venue where team won the match by highest run
pd.DataFrame(df.loc[df['win_by_runs']==max(df['win_by_runs']),'venue'])
# Out:
#                venue
# 43  Feroz Shah Kotla

# %%
# Venue where team won the match by highest wicket
pd.DataFrame(df.loc[df['win_by_wickets']==max(df['win_by_wickets']),'venue'])
# Out:
#                                                  venue
# 2               Saurashtra Cricket Association Stadium
# 34   Punjab Cricket Association IS Bindra Stadium, ...
# 71                          Dr DY Patil Sports Academy
# 119                                           Newlands
# 183                              M Chinnaswamy Stadium
# 298                                   Wankhede Stadium
# 376                             Sawai Mansingh Stadium
# 390         Punjab Cricket Association Stadium, Mohali
# 542                                   Feroz Shah Kotla
# 590             Saurashtra Cricket Association Stadium
# 683                             Holkar Cricket Stadium

# %% [markdown]
# ## 17.	Print the venue names where the team will won the match by lowest run and highest wicket

# %%
# Venue where team won the match by lowest run
pd.DataFrame(df.loc[df['win_by_runs']==min(df['win_by_runs']),'venue'])
# Out:
#                                                  venue
# 1              Maharashtra Cricket Association Stadium
# 2               Saurashtra Cricket Association Stadium
# 3                               Holkar Cricket Stadium
# 5            Rajiv Gandhi International Stadium, Uppal
# 6                                     Wankhede Stadium
# 7                               Holkar Cricket Stadium
# 9                                     Wankhede Stadium
# 10                                        Eden Gardens
# 11                               M Chinnaswamy Stadium
# 12              Saurashtra Cricket Association Stadium
# 15                                    Wankhede Stadium
# 17                                    Feroz Shah Kotla
# 21                              Holkar Cricket Stadium
# 22                                        Eden Gardens
# 24             Maharashtra Cricket Association Stadium
# 28             Maharashtra Cricket Association Stadium
# ...

# %% [markdown]
# ## 18.	Print umpire names who did the umpiring for maximum and minimum times

# %%
ser3=df['umpire2'].value_counts()
ser4=df['umpire1'].value_counts()
df3=pd.concat([ser3,ser4],axis=1,join='outer')
df3.fillna(0,inplace=True)
df3['sum']=df3['umpire1']+df3['umpire2']
print("Umpire with maximum number of times:")
print(df3[df3['sum']==max(df3['sum'])]['sum'])
print("\n\nUmpire with minimum number of times:")
print(df3[df3['sum']==min(df3['sum'])]['sum'])
# Out:
# Umpire with maximum number of times:
# S Ravi    106.0
# Name: sum, dtype: float64
#
#
# Umpire with minimum number of times:
# Nand Kishore     1.0
# Subroto Das      1.0
# Sundaram Ravi    1.0
# Name: sum, dtype: float64

# %% [markdown]
# ## ---------------------------------------------------------------------------------------------------------------------------------------
